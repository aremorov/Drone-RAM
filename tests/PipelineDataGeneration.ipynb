# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = np.asarray(Image.open("pipesTest1.png"))

# %%
type(Image.open("pipesTest1.png"))
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
img.shape
# Out:
# (1178, 1454, 4)

# %%
img[:,:,0].shape
# Out:
# (1178, 1454)

# %%
plt.imshow(img[700:1000,700:1000,0])
plt.colorbar()

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,2])
