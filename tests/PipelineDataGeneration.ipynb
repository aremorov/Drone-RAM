# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = np.asarray(Image.open("pipesTest1.png"))

# %%
img.shape
# Out:
# (1178, 1454, 4)

# %%
img[:,:,0].shape
# Out:
# (1178, 1454)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,1])

# %%
plt.imshow(img[:,:,2])
